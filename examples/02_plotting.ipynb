# %%
import sys
sys.path.append('../')
from stim_surface_code.memory import MemoryPatch
from stim_surface_code.stability import StabilityPatch
from stim_surface_code import noise
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Basic usage

# %%
m = MemoryPatch(5, 5, 5)
s = StabilityPatch(6,6,6, observable_basis='X')

m.plot_qubit_vals()
plt.title('Memory')
plt.show()

s.plot_qubit_vals()
plt.title('Stability')
plt.show()

# %%
plot_vals = np.random.random(len(m.all_qubits)) * 2

# %%
ax = plt.gca()
_, cbar = m.plot_qubit_vals(plot_vals, ax=ax, vmin=0, vmax=2, plot_text='val', val_fmt_fn=lambda x: f'{x:.2f}', font_size=10)
# ax.clear()
# m.plot_qubit_vals(plot_vals+1, ax=ax, vmax=2, cbar=cbar)
plt.show()
