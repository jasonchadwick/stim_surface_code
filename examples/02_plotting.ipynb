# %%
import sys
sys.path.append('../')
from stim_surface_code.memory import MemoryPatch
from stim_surface_code import noise
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Basic usage

# %%
m = MemoryPatch(5, 5, 5)
m.plot_qubit_vals()
plt.show()

# %%
plot_vals = np.random.random(len(m.all_qubits))

# %%
fig,ax = plt.subplots()
_, cbar = m.plot_qubit_vals(plot_vals, ax=ax, vmax=3)
ax.clear()
m.plot_qubit_vals(plot_vals+1, ax=ax, vmax=2, cbar=cbar)
plt.show()
